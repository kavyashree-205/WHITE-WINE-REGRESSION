# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
df_white=pd.read_csv("winequality-white.csv",delimiter=";")
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.2 KB

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
df_white.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
type(df_white)
# Out:
# pandas.core.frame.DataFrame

# %%
df_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
columns=df_white.columns
columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_white.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
feature=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
list(enumerate(feature))
# Out:
# [(0, 'fixed acidity'),
#  (1, 'volatile acidity'),
#  (2, 'citric acid'),
#  (3, 'residual sugar'),
#  (4, 'chlorides'),
#  (5, 'free sulfur dioxide'),
#  (6, 'total sulfur dioxide'),
#  (7, 'density'),
#  (8, 'pH'),
#  (9, 'sulphates'),
#  (10, 'alcohol'),
#  (11, 'quality')]

# %%
plt.figure(figsize=(8,5))
sns.countplot("quality",data=df_white)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(8,16))
plt.style.use("seaborn-whitegrid")
for i in enumerate(feature):
    plt.subplot(6,2,i[0]+1)
    sns.distplot(df_white[i[1]])
    plt.title("Distribution plot of "+str(i[1]),fontsize=15)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(7,16))
plt.style.use("seaborn-whitegrid")
for j in enumerate(feature):
    plt.subplot(6,2,j[0]+1)
    plt.boxplot(df_white[j[1]])
    plt.xlabel(j[1],fontsize=13)
    plt.title("Boxplot of "+str(i[1]))
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
plt.figure(figsize=(10,7))
a=df_white.corr()
sns.heatmap(a,annot=True,linewidths=.5)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
features=['fixed acidity','volatile acidity','residual sugar','chlorides','total sulfur dioxide','pH','sulphates','alcohol']

# %%
map_corr=df_white.corr()
map_corr[features]
# Out:
#                       fixed acidity  volatile acidity  residual sugar  \
# fixed acidity              1.000000         -0.022697        0.089021
# volatile acidity          -0.022697          1.000000        0.064286
# citric acid                0.289181         -0.149472        0.094212
# residual sugar             0.089021          0.064286        1.000000
# chlorides                  0.023086          0.070512        0.088685
# free sulfur dioxide       -0.049396         -0.097012        0.299098
# total sulfur dioxide       0.091070          0.089261        0.401439
# density                    0.265331          0.027114        0.838966
# pH                        -0.425858         -0.031915       -0.194133
# sulphates                 -0.017143         -0.035728       -0.026664
# alcohol                   -0.120881          0.067718       -0.450631
# quality                   -0.113663         -0.194723       -0.097577
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=df_white[features]
Y=df_white["quality"]
X.tail(10)
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  \
# 4888            6.8             0.220            1.20      0.052
# 4889            4.9             0.235           11.75      0.030
# 4890            6.1             0.340            2.20      0.036
# 4891            5.7             0.210            0.90      0.038
# 4892            6.5             0.230            1.30      0.032
# 4893            6.2             0.210            1.60      0.039
# 4894            6.6             0.320            8.00      0.047
# 4895            6.5             0.240            1.20      0.041
# 4896            5.5             0.290            1.10      0.022
# 4897            6.0             0.210            0.80      0.020
#
#       total sulfur dioxide    pH  sulphates  alcohol
# 4888                 127.0  3.04       0.54      9.2
# 4889                 118.0  3.07       0.50      9.4
# 4890                 100.0  3.06       0.44     11.8
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([-5.82103518e-02, -2.05325245e+00,  2.67411387e-02, -1.22328570e+00,
#         5.15905972e-04,  1.58965550e-01,  3.68471631e-01,  3.67643350e-01])

# %%
regressor.intercept_
# Out:
# 2.125848790528191

# %%
pred_train=regressor.predict(x_train)
pred_test=regressor.predict(x_test)

# %%
pred_train
# Out:
# array([5.07161095, 6.49833538, 5.81085293, ..., 5.73542118, 6.0029957 ,
#        5.05361911])

# %%
pred_test
# Out:
# array([5.70782874, 5.54785469, 6.04894856, ..., 6.25661829, 5.96211339,
#        5.96941464])

# %%
from sklearn import metrics

# %%
print("MEAN ABSOLUTE ERROR : ",metrics.mean_absolute_error(y_test,pred_test))
print("MEAN SQUARED ERROR : ",metrics.mean_squared_error(y_test,pred_test))
print("ROOT MEAN SQUARED ERROR : ",np.sqrt(metrics.mean_squared_error(y_test,pred_test)))
# Out:
# MEAN ABSOLUTE ERROR :  0.6114711076809435
# MEAN SQUARED ERROR :  0.604603563647728
# ROOT MEAN SQUARED ERROR :  0.7775625786055602

# %%
np.sqrt(metrics.mean_squared_error(y_train,pred_train))
# Out:
# 0.7493641098973187

# %%
coeffecients = pd.DataFrame(regressor.coef_,features)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                       Coeffecient
# fixed acidity           -0.058210
# volatile acidity        -2.053252
# residual sugar           0.026741
# chlorides               -1.223286
# total sulfur dioxide     0.000516
# pH                       0.158966
# sulphates                0.368472
# alcohol                  0.367643

# %%
regressor.intercept_
# Out:
# 2.125848790528191
